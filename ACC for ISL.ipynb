# %% [markdown]
# # 1. Import and Install Dependencies

# %%
# !pip install tensorflow==2.5.1 tensorflow-gpu==2.5.1 opencv-python mediapipe sklearn matplotlib
# Out:
# Requirement already satisfied: tensorflow==2.5.1 in c:\users\kdbor\anaconda3\lib\site-packages (2.5.1)
# Requirement already satisfied: tensorflow-gpu==2.5.1 in c:\users\kdbor\anaconda3\lib\site-packages (2.5.1)
# Requirement already satisfied: opencv-python in c:\users\kdbor\anaconda3\lib\site-packages (4.8.0.76)
# Requirement already satisfied: mediapipe in c:\users\kdbor\anaconda3\lib\site-packages (0.8.11)
# Requirement already satisfied: sklearn in c:\users\kdbor\anaconda3\lib\site-packages (0.0.post9)
# Requirement already satisfied: matplotlib in c:\users\kdbor\anaconda3\lib\site-packages (3.5.2)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\kdbor\anaconda3\lib\site-packages (from tensorflow==2.5.1) (1.12.1)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\kdbor\anaconda3\lib\site-packages (from tensorflow==2.5.1) (1.1.0)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0 in c:\users\kdbor\anaconda3\lib\site-packages (from tensorflow==2.5.1) (2.5.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\kdbor\anaconda3\lib\site-packages (from tensorflow==2.5.1) (1.1.2)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\kdbor\anaconda3\lib\site-packages (from tensorflow==2.5.1) (3.7.4.3)
# Requirement already satisfied: wheel~=0.35 in c:\users\kdbor\anaconda3\lib\site-packages (from tensorflow==2.5.1) (0.37.1)
# Requirement already satisfied: h5py~=3.1.0 in c:\users\kdbor\anaconda3\lib\site-packages (from tensorflow==2.5.1) (3.1.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\kdbor\anaconda3\lib\site-packages (from tensorflow==2.5.1) (3.3.0)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in c:\users\kdbor\anaconda3\lib\site-packages (from tensorflow==2.5.1) (2.5.0.dev2021032900)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\kdbor\anaconda3\lib\site-packages (from tensorflow==2.5.1) (0.2.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\kdbor\anaconda3\lib\site-packages (from tensorflow==2.5.1) (3.20.3)
# Requirement already satisfied: tensorboard~=2.5 in c:\users\kdbor\anaconda3\lib\site-packages (from tensorflow==2.5.1) (2.11.2)
# Requirement already satisfied: grpcio~=1.34.0 in c:\users\kdbor\anaconda3\lib\site-packages (from tensorflow==2.5.1) (1.34.1)
# Requirement already satisfied: numpy~=1.19.2 in c:\users\kdbor\anaconda3\lib\site-packages (from tensorflow==2.5.1) (1.19.5)
# Requirement already satisfied: gast==0.4.0 in c:\users\kdbor\anaconda3\lib\site-packages (from tensorflow==2.5.1) (0.4.0)
# Requirement already satisfied: six~=1.15.0 in c:\users\kdbor\anaconda3\lib\site-packages (from tensorflow==2.5.1) (1.15.0)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\kdbor\anaconda3\lib\site-packages (from tensorflow==2.5.1) (1.6.3)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\kdbor\anaconda3\lib\site-packages (from tensorflow==2.5.1) (1.12)
# Requirement already satisfied: absl-py~=0.10 in c:\users\kdbor\anaconda3\lib\site-packages (from tensorflow==2.5.1) (0.15.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\kdbor\anaconda3\lib\site-packages (from mediapipe) (21.4.0)
# Requirement already satisfied: opencv-contrib-python in c:\users\kdbor\anaconda3\lib\site-packages (from mediapipe) (4.8.0.76)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kdbor\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\kdbor\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kdbor\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kdbor\anaconda3\lib\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\kdbor\anaconda3\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\kdbor\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\kdbor\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\kdbor\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\kdbor\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1) (3.3.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\kdbor\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\kdbor\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1) (2.28.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\kdbor\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\kdbor\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1) (2.0.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\kdbor\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1) (2.23.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\kdbor\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1) (63.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\kdbor\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.1) (4.9)
# Requirement already satisfied: urllib3<2.0 in c:\users\kdbor\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.1) (1.26.11)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\kdbor\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.1) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\kdbor\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.1) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\kdbor\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.1) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kdbor\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.1) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\kdbor\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.1) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kdbor\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.1) (2022.9.14)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\kdbor\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.1) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\kdbor\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.1) (3.2.2)

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %% [markdown]
# # 2. Keypoints using MP Holistic

# %%
mp_holistic = mp.solutions.holistic 
mp_drawing = mp.solutions.drawing_utils

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) 
    image.flags.writeable = False                  
    results = model.process(image)                 
    image.flags.writeable = True                    
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) 
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION) 
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) 
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) 
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)

# %%
def draw_styled_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 

    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        ret, frame = cap.read()

        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        draw_styled_landmarks(image, results)

        cv2.imshow('OpenCV Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
results
# Out:
# mediapipe.python.solution_base.SolutionOutputs

# %%
draw_landmarks(frame, results)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # 3. Extract Keypoint Values

# %%
len(results.left_hand_landmarks.landmark)
# Out:
# 21

# %%
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)

# %%
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
result_test = extract_keypoints(results)

# %%
result_test
# Out:
# array([ 0.42309427,  0.49957269, -0.93779755, ...,  0.        ,
#         0.        ,  0.        ])

# %%
np.save('0', result_test)

# %%
np.load('0.npy')
# Out:
# array([ 0.42309427,  0.49957269, -0.93779755, ...,  0.        ,
#         0.        ,  0.        ])

# %% [markdown]
# # 4. Setup Folders for Collection

# %%
DATA_PATH = os.path.join('MP_Data') 

actions = np.array(['Hello', 'Good-Morning', 'Sorry', 'Friend', 'How-Are-You'])

no_sequences = 30

sequence_length = 30

start_folder = 0

# %%
for action in actions: 
    dirmax = np.max(np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int))
    for sequence in range(no_sequences+1):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %% [markdown]
# # 5. Collect Keypoint Values for Training and Testing

# %%
cap = cv2.VideoCapture(0)
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    for action in actions:
        for sequence in range(no_sequences):
            for frame_num in range(sequence_length):

                ret, frame = cap.read()

                image, results = mediapipe_detection(frame, holistic)

                draw_styled_landmarks(image, results)
                
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(500)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    cv2.imshow('OpenCV Feed', image)
                
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\kdbor\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\kdbor\AppData\Local\Temp\ipykernel_6748\192863153.py", line 17, in <module>
#     image, results = mediapipe_detection(frame, holistic)
#   File "C:\Users\kdbor\AppData\Local\Temp\ipykernel_6748\2065571785.py", line 4, in mediapipe_detection
#     results = model.process(image)                 # Make prediction
#   File "C:\Users\kdbor\anaconda3\lib\site-packages\mediapipe\python\solutions\holistic.py", line 160, in process
#     results = super().process(input_data={'image': image})
#   File "C:\Users\kdbor\anaconda3\lib\site-packages\mediapipe\python\solution_base.py", line 366, in process
#     self._graph.wait_until_idle()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\kdbor\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\kdbor\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\kdbor\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\kdbor\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\kdbor\anaconda3\lib\inspect.py", line 1543, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\kdbor\anaconda3\lib\inspect.py", line 1501, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\kdbor\anaconda3\lib\inspect.py", line 706, in getsourcefile
#     if os.path.exists(filename):
#   File "C:\Users\kdbor\anaconda3\lib\genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "C:\Users\kdbor\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\kdbor\AppData\Local\Temp\ipykernel_6748\192863153.py", line 17, in <module>
#     image, results = mediapipe_detection(frame, holistic)
#   File "C:\Users\kdbor\AppData\Local\Temp\ipykernel_6748\2065571785.py", line 4, in mediapipe_detection
#     results = model.process(image)                 # Make prediction
#   File "C:\Users\kdbor\anaconda3\lib\site-packages\mediapipe\python\solutions\holistic.py", line 160, in process
#     results = super().process(input_data={'image': image})
#   File "C:\Users\kdbor\anaconda3\lib\site-packages\mediapipe\python\solution_base.py", line 366, in process
#     self._graph.wait_until_idle()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\kdbor\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\kdbor\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\kdbor\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\kdbor\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2079, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "C:\Users\kdbor\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\kdbor\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\kdbor\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "C:\Users\kdbor\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\kdbor\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\kdbor\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\kdbor\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\kdbor\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\kdbor\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\kdbor\anaconda3\lib\inspect.py", line 1543, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\kdbor\anaconda3\lib\inspect.py", line 1501, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\kdbor\anaconda3\lib\inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\kdbor\anaconda3\lib\inspect.py", line 755, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "C:\Users\kdbor\anaconda3\lib\ntpath.py", line 664, in realpath
#     if _getfinalpathname(spath) == path:
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~\AppData\Local\Temp\ipykernel_6748\192863153.py in <module>
#      16                 # Make detections
# ---> 17                 image, results = mediapipe_detection(frame, holistic)
#      18
#
# ~\AppData\Local\Temp\ipykernel_6748\2065571785.py in mediapipe_detection(image, model)
#       3     image.flags.writeable = False                  # Image is no longer writeable
# ----> 4     results = model.process(image)                 # Make prediction
#       5     image.flags.writeable = True                   # Image is now writeable
#
# ~\anaconda3\lib\site-packages\mediapipe\python\solutions\holistic.py in process(self, image)
#     159
# --> 160     results = super().process(input_data={'image': image})
#     161     if results.pose_landmarks:  # pytype: disable=attribute-error
#
# ~\anaconda3\lib\site-packages\mediapipe\python\solution_base.py in process(self, input_data)
#     365
# --> 366     self._graph.wait_until_idle()
#     367     # Create a NamedTuple object where the field names are mapping to the graph
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2076                         # in the engines. This should return a list of strings.
# -> 2077                         stb = value._render_traceback_()
#    2078                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_ast_nodes(self, nodelist, cell_name, interactivity, compiler, result)
#    3376                         asy = compare(code)
# -> 3377                     if (await self.run_code(code, result,  async_=asy)):
#    3378                         return True
#
#     [... skipping hidden 1 frame]
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2078                     except Exception:
# -> 2079                         stb = self.InteractiveTB.structured_traceback(etype,
#    2080                                             value, tb, tb_offset=tb_offset)
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in find_recursion(etype, value, records)
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2076                         # in the engines. This should return a list of strings.
# -> 2077                         stb = value._render_traceback_()
#    2078                     except Exception:
#
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\async_helpers.py in _pseudo_sync_runner(coro)
#      76     """
#      77     try:
# ---> 78         coro.send(None)
#      79     except StopIteration as exc:
#      80         return exc.value
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple)
#    3183                     interactivity = 'async'
#    3184
# -> 3185                 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3186                        interactivity=interactivity, compiler=compiler, result=result)
#    3187
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_ast_nodes(self, nodelist, cell_name, interactivity, compiler, result)
#    3394             if result:
#    3395                 result.error_before_exec = sys.exc_info()[1]
# -> 3396             self.showtraceback()
#    3397             return True
#    3398
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2077                         stb = value._render_traceback_()
#    2078                     except Exception:
# -> 2079                         stb = self.InteractiveTB.structured_traceback(etype,
#    2080                                             value, tb, tb_offset=tb_offset)
#    2081
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1140         chained_exc_ids = set()
#    1141         while evalue:
# -> 1142             formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#    1143                                                                      chained_exceptions_tb_offset)
#    1144             exception = self.get_parts_of_chained_exception(evalue)
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 6. Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'Hello': 0, 'Good-Morning': 1, 'Sorry': 2, 'Friend': 3, 'How-Are-You': 4}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (150, 30, 1662)

# %%
np.array(labels).shape
# Out:
# (150,)

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (150, 30, 1662)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
y_test.shape
# Out:
# (8, 5)

# %% [markdown]
# # 7. Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
# Out:
# Epoch 1/2000
# 5/5 [==============================] - 7s 316ms/step - loss: 10.1488 - categorical_accuracy: 0.2465
# Epoch 2/2000
# 5/5 [==============================] - 1s 122ms/step - loss: 1.6152 - categorical_accuracy: 0.2394
# Epoch 3/2000
# 5/5 [==============================] - 1s 117ms/step - loss: 1.6462 - categorical_accuracy: 0.1831
# Epoch 4/2000
# 5/5 [==============================] - 1s 123ms/step - loss: 1.6910 - categorical_accuracy: 0.3239
# Epoch 5/2000
# 5/5 [==============================] - 1s 125ms/step - loss: 1.4881 - categorical_accuracy: 0.3521
# Epoch 6/2000
# 5/5 [==============================] - 1s 118ms/step - loss: 1.3689 - categorical_accuracy: 0.4437
# Epoch 7/2000
# 5/5 [==============================] - 1s 125ms/step - loss: 1.4765 - categorical_accuracy: 0.3521
# Epoch 8/2000
# 5/5 [==============================] - 1s 124ms/step - loss: 1.1132 - categorical_accuracy: 0.4577
# Epoch 9/2000
# 5/5 [==============================] - 1s 122ms/step - loss: 1.0283 - categorical_accuracy: 0.5915
# Epoch 10/2000
# 5/5 [==============================] - 1s 137ms/step - loss: 0.9891 - categorical_accuracy: 0.5282
# Epoch 11/2000
# 5/5 [==============================] - 1s 104ms/step - loss: 0.7450 - categorical_accuracy: 0.7324
# Epoch 12/2000
# 5/5 [==============================] - 0s 96ms/step - loss: 1.5703 - categorical_accuracy: 0.3803
# Epoch 13/2000
# 5/5 [==============================] - 1s 112ms/step - loss: 1.0570 - categorical_accuracy: 0.4507
# Epoch 14/2000
# 5/5 [==============================] - 1s 122ms/step - loss: 1.1525 - categorical_accuracy: 0.3944
# Epoch 15/2000
# 5/5 [==============================] - 1s 119ms/step - loss: 0.9471 - categorical_accuracy: 0.4577
# Epoch 16/2000
# 5/5 [==============================] - 1s 121ms/step - loss: 0.8432 - categorical_accuracy: 0.5986
# Epoch 17/2000
# 5/5 [==============================] - 1s 118ms/step - loss: 0.7269 - categorical_accuracy: 0.7113
# Epoch 18/2000
# 5/5 [==============================] - 1s 97ms/step - loss: 0.7236 - categorical_accuracy: 0.7042
# Epoch 19/2000
# 5/5 [==============================] - 1s 121ms/step - loss: 0.5587 - categorical_accuracy: 0.8028
# Epoch 20/2000
# 5/5 [==============================] - 1s 123ms/step - loss: 0.5542 - categorical_accuracy: 0.7394
# Epoch 21/2000
# 5/5 [==============================] - 1s 121ms/step - loss: 0.7642 - categorical_accuracy: 0.7817
# Epoch 22/2000
# 5/5 [==============================] - 1s 97ms/step - loss: 1.1818 - categorical_accuracy: 0.5352
# Epoch 23/2000
# 5/5 [==============================] - 1s 112ms/step - loss: 1.0201 - categorical_accuracy: 0.5423
# Epoch 24/2000
# 5/5 [==============================] - 1s 118ms/step - loss: 0.7598 - categorical_accuracy: 0.7465
# Epoch 25/2000
# 5/5 [==============================] - 1s 115ms/step - loss: 0.7246 - categorical_accuracy: 0.5423
# Epoch 26/2000
# 5/5 [==============================] - 0s 103ms/step - loss: 0.6237 - categorical_accuracy: 0.7394
# Epoch 27/2000
# 5/5 [==============================] - 1s 120ms/step - loss: 0.5748 - categorical_accuracy: 0.7817
# Epoch 28/2000
# 5/5 [==============================] - 1s 116ms/step - loss: 0.4872 - categorical_accuracy: 0.8028
# Epoch 29/2000
# 5/5 [==============================] - 1s 112ms/step - loss: 0.5416 - categorical_accuracy: 0.7394
# Epoch 30/2000
# 5/5 [==============================] - 1s 125ms/step - loss: 0.3452 - categorical_accuracy: 0.9014
# Epoch 31/2000
# 5/5 [==============================] - 1s 112ms/step - loss: 0.3091 - categorical_accuracy: 0.8944
# Epoch 32/2000
# 5/5 [==============================] - 1s 124ms/step - loss: 0.3597 - categorical_accuracy: 0.8803
# Epoch 33/2000
# 5/5 [==============================] - 1s 107ms/step - loss: 0.2491 - categorical_accuracy: 0.9366
# Epoch 34/2000
# 5/5 [==============================] - 1s 127ms/step - loss: 0.2260 - categorical_accuracy: 0.9296
# Epoch 35/2000
# 5/5 [==============================] - 1s 101ms/step - loss: 0.2269 - categorical_accuracy: 0.9014
# Epoch 36/2000
# 5/5 [==============================] - 1s 130ms/step - loss: 0.8116 - categorical_accuracy: 0.7042
# Epoch 37/2000
# 5/5 [==============================] - 1s 104ms/step - loss: 0.6784 - categorical_accuracy: 0.7394
# Epoch 38/2000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7501 - categorical_accuracy: 0.6250
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11688\647883075.py in <module>
# ----> 1 model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1176                 _r=1):
#    1177               callbacks.on_train_batch_begin(step)
# -> 1178               tmp_logs = self.train_function(iterator)
#    1179               if data_handler.should_sync:
#    1180                 context.async_wait()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    3021       (graph_function,
#    3022        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3023     return graph_function._call_flat(
#    3024         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3025
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1958         and executing_eagerly):
#    1959       # No tape is watching; skip to running the function.
# -> 1960       return self._build_call_outputs(self._inference_function.call(
#    1961           ctx, args, cancellation_manager=cancellation_manager))
#    1962     forward_backward = self._select_forward_and_backward_functions(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     589       with _InterpolateFunctionError(self):
#     590         if cancellation_manager is None:
# --> 591           outputs = execute.execute(
#     592               str(self.signature.name),
#     593               num_outputs=self._num_outputs,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 30, 64)            442112
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 30, 128)           98816
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 64)                49408
# _________________________________________________________________
# dense (Dense)                (None, 64)                4160
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 165
# =================================================================
# Total params: 596,741
# Trainable params: 596,741
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 8. Make Predictions

# %%
res = model.predict(X_test)

# %%
actions[np.argmax(res[4])]
# Out:
# 'Sorry'

# %%
actions[np.argmax(y_test[4])]
# Out:
# 'Sorry'

# %% [markdown]
# # 9. Save Weights

# %%
model.save('action.h5')

# %%
#del model

# %%
#model.load_weights('action.h5')

# %% [markdown]
# # 10. Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[7, 0],
#         [0, 1]],
#
#        [[6, 0],
#         [0, 2]],
#
#        [[6, 0],
#         [0, 2]],
#
#        [[7, 0],
#         [0, 1]],
#
#        [[6, 0],
#         [0, 2]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 1.0

# %% [markdown]
# # 11. Test in Real Time

# %%
from scipy import stats

# %%
sequence = []
sentence = []
predictions = []
threshold = 0.5

cap = cv2.VideoCapture(0)
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        ret, frame = cap.read()

        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        draw_styled_landmarks(image, results)
        
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        cv2.imshow('OpenCV Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# ...
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Sorry
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Good-Morning
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# How-Are-You
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# How-Are-You
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# How-Are-You
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# How-Are-You
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# How-Are-You
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# How-Are-You
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# How-Are-You
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# How-Are-You
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# How-Are-You
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# How-Are-You
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# How-Are-You
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Friend
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
